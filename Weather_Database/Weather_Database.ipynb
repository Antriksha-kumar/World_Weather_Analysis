# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.00, high = 90.00, size = 2000)
lngs = np.random.uniform(low = -90.00, high = 90.00, size = 2000)

# zip the lats and langs together as pairs

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.

cities = []
# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count

len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in th eset of 50
    if(i%50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
     # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# To handle the errors     
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_weather
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description
                         })
            

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | roald
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | san juan
# Processing Record 5 of Set 1 | quatre cocos
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | copiapo
# Processing Record 8 of Set 1 | porto novo
# Processing Record 9 of Set 1 | izhma
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | yenagoa
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | vila velha
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | yarmouth
# Processing Record 17 of Set 1 | mindelo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | vardo
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | gonbad-e qabus
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | aasiaat
# Processing Record 27 of Set 1 | santa marta
# Processing Record 28 of Set 1 | leh
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | waw
# Processing Record 31 of Set 1 | rawson
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | jalu
# Processing Record 35 of Set 1 | longyearbyen
# Processing Record 36 of Set 1 | touros
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | killybegs
# Processing Record 39 of Set 1 | sinnamary
# Processing Record 40 of Set 1 | hamilton
# Processing Record 41 of Set 1 | vestmanna
# Processing Record 42 of Set 1 | kovdor
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | vila franca do campo
# Processing Record 45 of Set 1 | itaituba
# Processing Record 46 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 1 | foumban
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | niceville
# Processing Record 50 of Set 1 | qandala
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | zaraza
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | usinsk
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | atar
# Processing Record 9 of Set 2 | kruisfontein
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | yashkul
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | bardiyah
# Processing Record 15 of Set 2 | pudozh
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 2 | pocone
# Processing Record 19 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 2 | pangnirtung
# Processing Record 21 of Set 2 | quelimane
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | riyadh
# Processing Record 24 of Set 2 | plouzane
# Processing Record 25 of Set 2 | vachi
# Processing Record 26 of Set 2 | bure
# Processing Record 27 of Set 2 | saint-francois
# Processing Record 28 of Set 2 | saint-georges
# Processing Record 29 of Set 2 | arlit
# Processing Record 30 of Set 2 | abu kamal
# Processing Record 31 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 2 | khandbari
# Processing Record 33 of Set 2 | carutapera
# Processing Record 34 of Set 2 | havoysund
# Processing Record 35 of Set 2 | moron
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | mukhanovo
# City not found. Skipping...
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | dovolnoye
# Processing Record 40 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 2 | rabo de peixe
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | suez
# Processing Record 44 of Set 2 | adrano
# Processing Record 45 of Set 2 | keene
# Processing Record 46 of Set 2 | kulhudhuffushi
# Processing Record 47 of Set 2 | qaqortoq
# Processing Record 48 of Set 2 | moreira sales
# Processing Record 49 of Set 2 | nebug
# Processing Record 50 of Set 2 | muros
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | irondequoit
# Processing Record 4 of Set 3 | givors
# Processing Record 5 of Set 3 | nadym
# Processing Record 6 of Set 3 | diego de almagro
# Processing Record 7 of Set 3 | tessalit
# Processing Record 8 of Set 3 | bezhetsk
# Processing Record 9 of Set 3 | grand gaube
# Processing Record 10 of Set 3 | noyabrsk
# Processing Record 11 of Set 3 | togur
# Processing Record 12 of Set 3 | portpatrick
# City not found. Skipping...
# Processing Record 13 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | kasane
# Processing Record 16 of Set 3 | mtsensk
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | camacha
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | praia
# Processing Record 21 of Set 3 | inverness
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | treinta y tres
# Processing Record 24 of Set 3 | mogwase
# Processing Record 25 of Set 3 | bay roberts
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | west bay
# Processing Record 28 of Set 3 | shentala
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | cidreira
# Processing Record 31 of Set 3 | kulu
# Processing Record 32 of Set 3 | cockburn town
# Processing Record 33 of Set 3 | rapla
# Processing Record 34 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 3 | merrill
# Processing Record 36 of Set 3 | amaigbo
# Processing Record 37 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 3 | shubarkuduk
# Processing Record 39 of Set 3 | jumla
# Processing Record 40 of Set 3 | natal
# Processing Record 41 of Set 3 | rosetta
# Processing Record 42 of Set 3 | polovinnoye
# Processing Record 43 of Set 3 | galle
# Processing Record 44 of Set 3 | scarborough
# Processing Record 45 of Set 3 | ugoofaaru
# Processing Record 46 of Set 3 | surt
# Processing Record 47 of Set 3 | bubaque
# Processing Record 48 of Set 3 | baturyn
# Processing Record 49 of Set 3 | kielce
# Processing Record 50 of Set 3 | najran
# Processing Record 1 of Set 4 | le vauclin
# Processing Record 2 of Set 4 | beyneu
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | urucara
# Processing Record 5 of Set 4 | matagami
# Processing Record 6 of Set 4 | paratinga
# Processing Record 7 of Set 4 | tim
# Processing Record 8 of Set 4 | kismayo
# Processing Record 9 of Set 4 | ampanihy
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | mafinga
# Processing Record 12 of Set 4 | santa isabel do rio negro
# Processing Record 13 of Set 4 | pishin
# Processing Record 14 of Set 4 | marsa matruh
# Processing Record 15 of Set 4 | kralendijk
# Processing Record 16 of Set 4 | vredendal
# Processing Record 17 of Set 4 | rocha
# Processing Record 18 of Set 4 | balfour
# Processing Record 19 of Set 4 | montepuez
# Processing Record 20 of Set 4 | khash
# Processing Record 21 of Set 4 | berlevag
# Processing Record 22 of Set 4 | taft
# Processing Record 23 of Set 4 | maniitsoq
# Processing Record 24 of Set 4 | lewisporte
# Processing Record 25 of Set 4 | husavik
# Processing Record 26 of Set 4 | huambo
# Processing Record 27 of Set 4 | peniche
# Processing Record 28 of Set 4 | taltal
# Processing Record 29 of Set 4 | dapaong
# Processing Record 30 of Set 4 | port elizabeth
# Processing Record 31 of Set 4 | port-gentil
# Processing Record 32 of Set 4 | nioro
# Processing Record 33 of Set 4 | buraydah
# Processing Record 34 of Set 4 | minas
# Processing Record 35 of Set 4 | valdivia
# Processing Record 36 of Set 4 | saint-pierre
# Processing Record 37 of Set 4 | pathalgaon
# Processing Record 38 of Set 4 | adrar
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 41 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 4 | maamba
# Processing Record 43 of Set 4 | havelock
# Processing Record 44 of Set 4 | petukhovo
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | boddam
# Processing Record 48 of Set 4 | cayenne
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 50 of Set 4 | karakose
# City not found. Skipping...
# Processing Record 1 of Set 5 | koplik
# Processing Record 2 of Set 5 | querecotillo
# Processing Record 3 of Set 5 | eyl
# Processing Record 4 of Set 5 | sao filipe
# Processing Record 5 of Set 5 | hyvinkaa
# Processing Record 6 of Set 5 | welkom
# Processing Record 7 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 5 | bandarbeyla
# Processing Record 9 of Set 5 | san luis
# Processing Record 10 of Set 5 | tazovskiy
# Processing Record 11 of Set 5 | olafsvik
# Processing Record 12 of Set 5 | ilhabela
# Processing Record 13 of Set 5 | sakakah
# Processing Record 14 of Set 5 | nkwerre
# Processing Record 15 of Set 5 | pitea
# Processing Record 16 of Set 5 | henties bay
# Processing Record 17 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 18 of Set 5 | burla
# Processing Record 19 of Set 5 | mana
# Processing Record 20 of Set 5 | felipe carrillo puerto
# Processing Record 21 of Set 5 | mirpur mathelo
# Processing Record 22 of Set 5 | chambersburg
# Processing Record 23 of Set 5 | usvyaty
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 26 of Set 5 | aden
# Processing Record 27 of Set 5 | shorapani
# Processing Record 28 of Set 5 | aqtobe
# Processing Record 29 of Set 5 | oranjestad
# Processing Record 30 of Set 5 | mumford
# Processing Record 31 of Set 5 | charlestown
# Processing Record 32 of Set 5 | sloboda
# Processing Record 33 of Set 5 | sur
# Processing Record 34 of Set 5 | saint-augustin
# Processing Record 35 of Set 5 | torbay
# Processing Record 36 of Set 5 | malanje
# Processing Record 37 of Set 5 | santiago
# Processing Record 38 of Set 5 | balkanabat
# Processing Record 39 of Set 5 | manama
# Processing Record 40 of Set 5 | qaanaaq
# Processing Record 41 of Set 5 | lundazi
# Processing Record 42 of Set 5 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 5 | kargasok
# Processing Record 44 of Set 5 | gore
# Processing Record 45 of Set 5 | christiana
# Processing Record 46 of Set 5 | margate
# Processing Record 47 of Set 5 | marzuq
# Processing Record 48 of Set 5 | harper
# Processing Record 49 of Set 5 | dzilam gonzalez
# Processing Record 50 of Set 5 | melioratorov
# Processing Record 1 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 6 | altay
# Processing Record 3 of Set 6 | salinas
# Processing Record 4 of Set 6 | mehamn
# Processing Record 5 of Set 6 | broska
# Processing Record 6 of Set 6 | bathsheba
# Processing Record 7 of Set 6 | thinadhoo
# Processing Record 8 of Set 6 | adeje
# Processing Record 9 of Set 6 | otjimbingwe
# Processing Record 10 of Set 6 | conil
# Processing Record 11 of Set 6 | sao felix do xingu
# Processing Record 12 of Set 6 | sisimiut
# Processing Record 13 of Set 6 | ambilobe
# Processing Record 14 of Set 6 | affery
# Processing Record 15 of Set 6 | salalah
# Processing Record 16 of Set 6 | ponta delgada
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | coquimbo
# Processing Record 20 of Set 6 | chapais
# Processing Record 21 of Set 6 | sambava
# Processing Record 22 of Set 6 | kansanshi
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 6 | zabid
# Processing Record 26 of Set 6 | mapiripan
# Processing Record 27 of Set 6 | kattivakkam
# Processing Record 28 of Set 6 | keti bandar
# Processing Record 29 of Set 6 | itarema
# Processing Record 30 of Set 6 | biarritz
# Processing Record 31 of Set 6 | kongolo
# Processing Record 32 of Set 6 | tanout
# Processing Record 33 of Set 6 | mangan
# Processing Record 34 of Set 6 | kasauli
# Processing Record 35 of Set 6 | mendi
# Processing Record 36 of Set 6 | beruni
# City not found. Skipping...
# Processing Record 37 of Set 6 | sao miguel do araguaia
# Processing Record 38 of Set 6 | podgornoye
# Processing Record 39 of Set 6 | alenquer
# Processing Record 40 of Set 6 | el alto
# Processing Record 41 of Set 6 | benjamin aceval
# Processing Record 42 of Set 6 | pueblo nuevo
# Processing Record 43 of Set 6 | darab
# Processing Record 44 of Set 6 | gat
# Processing Record 45 of Set 6 | giera
# Processing Record 46 of Set 6 | kamenka
# Processing Record 47 of Set 6 | pitimbu
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | baryatino
# Processing Record 50 of Set 6 | calera
# Processing Record 1 of Set 7 | iquique
# Processing Record 2 of Set 7 | benavente
# Processing Record 3 of Set 7 | wattegama
# Processing Record 4 of Set 7 | vestmannaeyjar
# Processing Record 5 of Set 7 | sergeyevka
# Processing Record 6 of Set 7 | manadhoo
# Processing Record 7 of Set 7 | le moule
# Processing Record 8 of Set 7 | zonguldak
# Processing Record 9 of Set 7 | kalmunai
# Processing Record 10 of Set 7 | tevriz
# Processing Record 11 of Set 7 | andilamena
# Processing Record 12 of Set 7 | derzhavinsk
# Processing Record 13 of Set 7 | paoua
# Processing Record 14 of Set 7 | tucupita
# Processing Record 15 of Set 7 | nouadhibou
# Processing Record 16 of Set 7 | graaff-reinet
# Processing Record 17 of Set 7 | yarada
# Processing Record 18 of Set 7 | oussouye
# Processing Record 19 of Set 7 | zhezkazgan
# Processing Record 20 of Set 7 | quepos
# Processing Record 21 of Set 7 | tonj
# Processing Record 22 of Set 7 | acarau
# Processing Record 23 of Set 7 | sirajganj
# Processing Record 24 of Set 7 | ihlow
# Processing Record 25 of Set 7 | mullovka
# Processing Record 26 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 7 | karlshamn
# Processing Record 28 of Set 7 | jyvaskyla
# Processing Record 29 of Set 7 | belyy yar
# Processing Record 30 of Set 7 | pasvalys
# Processing Record 31 of Set 7 | kyabe
# Processing Record 32 of Set 7 | kabalo
# Processing Record 33 of Set 7 | tornio
# Processing Record 34 of Set 7 | anuradhapura
# Processing Record 35 of Set 7 | yanam
# Processing Record 36 of Set 7 | presidente dutra
# Processing Record 37 of Set 7 | abu samrah
# Processing Record 38 of Set 7 | malakal
# Processing Record 39 of Set 7 | kargat
# Processing Record 40 of Set 7 | nuh
# Processing Record 41 of Set 7 | cabo rojo
# Processing Record 42 of Set 7 | gidole
# Processing Record 43 of Set 7 | bilma
# Processing Record 44 of Set 7 | caravelas
# Processing Record 45 of Set 7 | demyansk
# Processing Record 46 of Set 7 | brunico
# Processing Record 47 of Set 7 | elizabeth city
# Processing Record 48 of Set 7 | vagur
# Processing Record 49 of Set 7 | vereshchagino
# Processing Record 50 of Set 7 | shenkursk
# Processing Record 1 of Set 8 | umm lajj
# Processing Record 2 of Set 8 | sihora
# Processing Record 3 of Set 8 | rognan
# Processing Record 4 of Set 8 | alipur
# Processing Record 5 of Set 8 | lyngseidet
# Processing Record 6 of Set 8 | volot
# Processing Record 7 of Set 8 | richards bay
# Processing Record 8 of Set 8 | malartic
# Processing Record 9 of Set 8 | grand-lahou
# Processing Record 10 of Set 8 | guaiuba
# Processing Record 11 of Set 8 | doha
# Processing Record 12 of Set 8 | sawakin
# Processing Record 13 of Set 8 | nicoya
# Processing Record 14 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 15 of Set 8 | molokovo
# Processing Record 16 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 8 | lushoto
# Processing Record 18 of Set 8 | tutoia
# Processing Record 19 of Set 8 | upata
# Processing Record 20 of Set 8 | shu
# Processing Record 21 of Set 8 | plettenberg bay
# Processing Record 22 of Set 8 | arbazh
# Processing Record 23 of Set 8 | sao lourenco do sul
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | peterhead
# Processing Record 26 of Set 8 | shelburne
# Processing Record 27 of Set 8 | girne
# Processing Record 28 of Set 8 | inhambane
# Processing Record 29 of Set 8 | amapa
# Processing Record 30 of Set 8 | senekal
# Processing Record 31 of Set 8 | abonnema
# Processing Record 32 of Set 8 | damghan
# Processing Record 33 of Set 8 | huarmey
# Processing Record 34 of Set 8 | port shepstone
# Processing Record 35 of Set 8 | mancio lima
# Processing Record 36 of Set 8 | gazni
# City not found. Skipping...
# Processing Record 37 of Set 8 | mahon
# Processing Record 38 of Set 8 | pirai do sul
# Processing Record 39 of Set 8 | sharan
# Processing Record 40 of Set 8 | tombouctou
# Processing Record 41 of Set 8 | wexford
# Processing Record 42 of Set 8 | sistranda
# Processing Record 43 of Set 8 | opuwo
# Processing Record 44 of Set 8 | muyezerskiy
# Processing Record 45 of Set 8 | coihaique
# Processing Record 46 of Set 8 | mashhad
# Processing Record 47 of Set 8 | kushmurun
# Processing Record 48 of Set 8 | awbari
# Processing Record 49 of Set 8 | antofagasta
# Processing Record 50 of Set 8 | kashi
# Processing Record 1 of Set 9 | valparaiso
# Processing Record 2 of Set 9 | mamallapuram
# Processing Record 3 of Set 9 | bud
# Processing Record 4 of Set 9 | nanuque
# Processing Record 5 of Set 9 | holme
# Processing Record 6 of Set 9 | nieuwpoort
# Processing Record 7 of Set 9 | pilna
# Processing Record 8 of Set 9 | la sarre
# Processing Record 9 of Set 9 | verkhniy uslon
# Processing Record 10 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 9 | kalia
# Processing Record 12 of Set 9 | los llanos de aridane
# Processing Record 13 of Set 9 | ornskoldsvik
# Processing Record 14 of Set 9 | manjacaze
# Processing Record 15 of Set 9 | morondava
# Processing Record 16 of Set 9 | abu zabad
# Processing Record 17 of Set 9 | barcelos
# Processing Record 18 of Set 9 | bolshiye dvory
# City not found. Skipping...
# Processing Record 19 of Set 9 | jaque
# Processing Record 20 of Set 9 | umm kaddadah
# Processing Record 21 of Set 9 | turukhansk
# Processing Record 22 of Set 9 | benjamin constant
# Processing Record 23 of Set 9 | zvishavane
# Processing Record 24 of Set 9 | sitio novo do tocantins
# Processing Record 25 of Set 9 | cullman
# Processing Record 26 of Set 9 | guantanamo
# Processing Record 27 of Set 9 | campbellsville
# Processing Record 28 of Set 9 | puerto narino
# Processing Record 29 of Set 9 | dutlwe
# Processing Record 30 of Set 9 | oistins
# Processing Record 31 of Set 9 | kita
# Processing Record 32 of Set 9 | sao joao da barra
# Processing Record 33 of Set 9 | villafranca de los barros
# Processing Record 34 of Set 9 | mahajanga
# Processing Record 35 of Set 9 | albany
# Processing Record 36 of Set 9 | iskateley
# Processing Record 37 of Set 9 | bageshwar
# Processing Record 38 of Set 9 | guayaramerin
# Processing Record 39 of Set 9 | toguchin
# Processing Record 40 of Set 9 | duque de caxias
# Processing Record 41 of Set 9 | kavaratti
# Processing Record 42 of Set 9 | maragogi
# Processing Record 43 of Set 9 | makuyuni
# Processing Record 44 of Set 9 | hit
# Processing Record 45 of Set 9 | pederneiras
# Processing Record 46 of Set 9 | ecoporanga
# Processing Record 47 of Set 9 | ipatovo
# Processing Record 48 of Set 9 | havre-saint-pierre
# Processing Record 49 of Set 9 | okakarara
# Processing Record 50 of Set 9 | carnarvon
# Processing Record 1 of Set 10 | tarn taran
# Processing Record 2 of Set 10 | pafos
# Processing Record 3 of Set 10 | nsanje
# Processing Record 4 of Set 10 | escanaba
# Processing Record 5 of Set 10 | geraldton
# Processing Record 6 of Set 10 | dalvik
# Processing Record 7 of Set 10 | kemijarvi
# Processing Record 8 of Set 10 | hofn
# Processing Record 9 of Set 10 | sao jose do belmonte
# Processing Record 10 of Set 10 | gambo
# Processing Record 11 of Set 10 | kokstad
# Processing Record 12 of Set 10 | jesup
# Processing Record 13 of Set 10 | arkhipo-osipovka
# Processing Record 14 of Set 10 | yazykovo
# Processing Record 15 of Set 10 | reconquista
# Processing Record 16 of Set 10 | luderitz
# Processing Record 17 of Set 10 | vagay
# Processing Record 18 of Set 10 | laguna
# Processing Record 19 of Set 10 | muslyumovo
# Processing Record 20 of Set 10 | yar-sale
# Processing Record 21 of Set 10 | dawlatabad
# Processing Record 22 of Set 10 | padang
# Processing Record 23 of Set 10 | burica
# City not found. Skipping...
# Processing Record 24 of Set 10 | leyland
# Processing Record 25 of Set 10 | astana
# Processing Record 26 of Set 10 | pimentel
# Processing Record 27 of Set 10 | jaisalmer
# Processing Record 28 of Set 10 | kangaatsiaq
# Processing Record 29 of Set 10 | savantvadi
# Processing Record 30 of Set 10 | hambantota
# Processing Record 31 of Set 10 | picos
# Processing Record 32 of Set 10 | muli
# Processing Record 33 of Set 10 | chanika
# Processing Record 34 of Set 10 | fort walton beach
# Processing Record 35 of Set 10 | brodowski
# Processing Record 36 of Set 10 | ipixuna
# Processing Record 37 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 10 | brae
# Processing Record 39 of Set 10 | podporozhye
# Processing Record 40 of Set 10 | fereydun kenar
# Processing Record 41 of Set 10 | andenes
# Processing Record 42 of Set 10 | atasu
# Processing Record 43 of Set 10 | shurugwi
# Processing Record 44 of Set 10 | kharan
# Processing Record 45 of Set 10 | puchezh
# Processing Record 46 of Set 10 | port-cartier
# Processing Record 47 of Set 10 | santa cruz de la palma
# Processing Record 48 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 10 | alekseyevka
# Processing Record 50 of Set 10 | villa rica
# Processing Record 1 of Set 11 | walvis bay
# Processing Record 2 of Set 11 | florianopolis
# Processing Record 3 of Set 11 | bani walid
# Processing Record 4 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 5 of Set 11 | saint anthony
# Processing Record 6 of Set 11 | aklera
# Processing Record 7 of Set 11 | san carlos de bariloche
# Processing Record 8 of Set 11 | wilmington
# Processing Record 9 of Set 11 | jiwani
# Processing Record 10 of Set 11 | jacareacanga
# Processing Record 11 of Set 11 | high rock
# Processing Record 12 of Set 11 | alakurtti
# Processing Record 13 of Set 11 | aksarka
# Processing Record 14 of Set 11 | donskoye
# Processing Record 15 of Set 11 | haguenau
# Processing Record 16 of Set 11 | abnub
# Processing Record 17 of Set 11 | itamaraca
# Processing Record 18 of Set 11 | alta floresta
# Processing Record 19 of Set 11 | pizarro
# Processing Record 20 of Set 11 | gamba
# Processing Record 21 of Set 11 | almunecar
# Processing Record 22 of Set 11 | sabha
# Processing Record 23 of Set 11 | glossa
# Processing Record 24 of Set 11 | faya
# Processing Record 25 of Set 11 | chichawatni
# Processing Record 26 of Set 11 | necochea
# Processing Record 27 of Set 11 | gazli
# Processing Record 28 of Set 11 | druzhba
# Processing Record 29 of Set 11 | araouane
# Processing Record 30 of Set 11 | dingle
# Processing Record 31 of Set 11 | rio grande
# Processing Record 32 of Set 11 | ninotsminda
# Processing Record 33 of Set 11 | yokadouma
# Processing Record 34 of Set 11 | aksu
# Processing Record 35 of Set 11 | marrakesh
# Processing Record 36 of Set 11 | trairi
# Processing Record 37 of Set 11 | puerto del rosario
# Processing Record 38 of Set 11 | corinto
# Processing Record 39 of Set 11 | seydi
# Processing Record 40 of Set 11 | amot
# Processing Record 41 of Set 11 | khora
# Processing Record 42 of Set 11 | gien
# Processing Record 43 of Set 11 | nurota
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | palafrugell
# Processing Record 46 of Set 11 | westport
# Processing Record 47 of Set 11 | guarapari
# Processing Record 48 of Set 11 | zaza del medio
# Processing Record 49 of Set 11 | kedougou
# Processing Record 50 of Set 11 | gaujani
# Processing Record 1 of Set 12 | bafq
# Processing Record 2 of Set 12 | santa maria do suacui
# Processing Record 3 of Set 12 | sechura
# Processing Record 4 of Set 12 | gornopravdinsk
# Processing Record 5 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 12 | romanovskaya
# Processing Record 7 of Set 12 | onverwacht
# Processing Record 8 of Set 12 | barranca
# Processing Record 9 of Set 12 | carrickmacross
# Processing Record 10 of Set 12 | thompson
# Processing Record 11 of Set 12 | balykshi
# Processing Record 12 of Set 12 | dakar
# Processing Record 13 of Set 12 | lagoa
# Processing Record 14 of Set 12 | raudeberg
# Processing Record 15 of Set 12 | bonavista
# Processing Record 16 of Set 12 | colesberg
# Processing Record 17 of Set 12 | moose factory
# Processing Record 18 of Set 12 | isoka
# Processing Record 19 of Set 12 | paracuru
# Processing Record 20 of Set 12 | hundested
# Processing Record 21 of Set 12 | vincennes
# Processing Record 22 of Set 12 | benghazi
# Processing Record 23 of Set 12 | samana
# Processing Record 24 of Set 12 | nikolskoye
# Processing Record 25 of Set 12 | santa rosa
# Processing Record 26 of Set 12 | axim
# Processing Record 27 of Set 12 | swakopmund
# Processing Record 28 of Set 12 | oyem
# Processing Record 29 of Set 12 | atbasar
# Processing Record 30 of Set 12 | urfa
# City not found. Skipping...
# Processing Record 31 of Set 12 | kapiri mposhi
# Processing Record 32 of Set 12 | muisne
# Processing Record 33 of Set 12 | islampur
# Processing Record 34 of Set 12 | oktyabrskiy
# Processing Record 35 of Set 12 | barentu
# Processing Record 36 of Set 12 | ferkessedougou
# Processing Record 37 of Set 12 | haifa
# Processing Record 38 of Set 12 | volchikha
# Processing Record 39 of Set 12 | chinsali
# Processing Record 40 of Set 12 | coruripe
# Processing Record 41 of Set 12 | mandera
# Processing Record 42 of Set 12 | butka
# Processing Record 43 of Set 12 | le pont-de-claix
# Processing Record 44 of Set 12 | the valley
# Processing Record 45 of Set 12 | ous
# Processing Record 46 of Set 12 | batticaloa
# Processing Record 47 of Set 12 | korcula
# Processing Record 48 of Set 12 | kahta
# Processing Record 49 of Set 12 | strelka
# Processing Record 50 of Set 12 | tuscaloosa
# Processing Record 1 of Set 13 | kentau
# Processing Record 2 of Set 13 | blackpool
# Processing Record 3 of Set 13 | pozo colorado
# Processing Record 4 of Set 13 | piacabucu
# Processing Record 5 of Set 13 | cap malheureux
# Processing Record 6 of Set 13 | korhogo
# Processing Record 7 of Set 13 | nirmali
# Processing Record 8 of Set 13 | ivankiv
# Processing Record 9 of Set 13 | padilla
# Processing Record 10 of Set 13 | san andres
# Processing Record 11 of Set 13 | alto araguaia
# Processing Record 12 of Set 13 | ust-tarka
# Processing Record 13 of Set 13 | general roca
# Processing Record 14 of Set 13 | kesova gora
# Processing Record 15 of Set 13 | buritizeiro
# Processing Record 16 of Set 13 | ambanja
# Processing Record 17 of Set 13 | altamira
# Processing Record 18 of Set 13 | isilkul
# Processing Record 19 of Set 13 | sovetskiy
# Processing Record 20 of Set 13 | carikar
# City not found. Skipping...
# Processing Record 21 of Set 13 | ituporanga
# Processing Record 22 of Set 13 | muzhi
# Processing Record 23 of Set 13 | male
# Processing Record 24 of Set 13 | medea
# Processing Record 25 of Set 13 | porto velho
# Processing Record 26 of Set 13 | rumonge
# Processing Record 27 of Set 13 | maloy
# Processing Record 28 of Set 13 | cahors
# Processing Record 29 of Set 13 | ostersund
# Processing Record 30 of Set 13 | shahr-e babak
# Processing Record 31 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 13 | salinopolis
# Processing Record 33 of Set 13 | presidencia roque saenz pena
# Processing Record 34 of Set 13 | madison
# Processing Record 35 of Set 13 | sao jose da coroa grande
# Processing Record 36 of Set 13 | grindavik
# Processing Record 37 of Set 13 | san lawrenz
# Processing Record 38 of Set 13 | bodden town
# Processing Record 39 of Set 13 | soyo
# Processing Record 40 of Set 13 | ibaiti
# Processing Record 41 of Set 13 | kozhva
# Processing Record 42 of Set 13 | sal rei
# Processing Record 43 of Set 13 | santa cruz
# Processing Record 44 of Set 13 | ronne
# Processing Record 45 of Set 13 | puerto carreno
# Processing Record 46 of Set 13 | kjollefjord
# Processing Record 47 of Set 13 | dombas
# Processing Record 48 of Set 13 | saint-joseph
# Processing Record 49 of Set 13 | matay
# Processing Record 50 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 1 of Set 14 | nizhniy odes
# Processing Record 2 of Set 14 | mangrol
# Processing Record 3 of Set 14 | mitsamiouli
# Processing Record 4 of Set 14 | moura
# Processing Record 5 of Set 14 | kalya
# Processing Record 6 of Set 14 | arona
# Processing Record 7 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 14 | horn
# Processing Record 9 of Set 14 | mogadishu
# Processing Record 10 of Set 14 | sorland
# Processing Record 11 of Set 14 | luau
# Processing Record 12 of Set 14 | forio
# Processing Record 13 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 14 | solton
# Processing Record 15 of Set 14 | parintins
# Processing Record 16 of Set 14 | gaya
# Processing Record 17 of Set 14 | yarim
# Processing Record 18 of Set 14 | oranjemund
# Processing Record 19 of Set 14 | pangody
# Processing Record 20 of Set 14 | omboue
# Processing Record 21 of Set 14 | matara
# Processing Record 22 of Set 14 | kuryk
# Processing Record 23 of Set 14 | youghal
# Processing Record 24 of Set 14 | ventspils
# Processing Record 25 of Set 14 | virginia beach
# Processing Record 26 of Set 14 | pandamatenga
# Processing Record 27 of Set 14 | erzurum
# Processing Record 28 of Set 14 | acari
# Processing Record 29 of Set 14 | salym
# Processing Record 30 of Set 14 | honningsvag
# Processing Record 31 of Set 14 | becerril
# Processing Record 32 of Set 14 | kristianstad
# Processing Record 33 of Set 14 | catia la mar
# Processing Record 34 of Set 14 | rampur
# Processing Record 35 of Set 14 | zatoka
# Processing Record 36 of Set 14 | humberto de campos
# Processing Record 37 of Set 14 | garoua boulai
# Processing Record 38 of Set 14 | zaysan
# Processing Record 39 of Set 14 | marsh harbour
# Processing Record 40 of Set 14 | maldonado
# Processing Record 41 of Set 14 | chimbote
# Processing Record 42 of Set 14 | capreol
# Processing Record 43 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 14 | vasilyevskiy mokh
# Processing Record 45 of Set 14 | nuuk
# Processing Record 46 of Set 14 | maputo
# Processing Record 47 of Set 14 | manaure
# Processing Record 48 of Set 14 | hearst
# Processing Record 49 of Set 14 | cobija
# Processing Record 50 of Set 14 | tahta
# Processing Record 1 of Set 15 | ovalle
# Processing Record 2 of Set 15 | praia grande
# Processing Record 3 of Set 15 | ubrique
# Processing Record 4 of Set 15 | gazojak
# Processing Record 5 of Set 15 | saint-paul
# Processing Record 6 of Set 15 | baherden
# Processing Record 7 of Set 15 | dudinka
# Processing Record 8 of Set 15 | clarence town
# Processing Record 9 of Set 15 | shatrovo
# Processing Record 10 of Set 15 | bakchar
# Processing Record 11 of Set 15 | venkatagiri
# Processing Record 12 of Set 15 | segezha
# Processing Record 13 of Set 15 | yantarnyy
# Processing Record 14 of Set 15 | olinda
# Processing Record 15 of Set 15 | srisailam
# Processing Record 16 of Set 15 | grootfontein
# Processing Record 17 of Set 15 | taoudenni
# Processing Record 18 of Set 15 | oriximina
# Processing Record 19 of Set 15 | mount holly
# Processing Record 20 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 15 | bam
# Processing Record 22 of Set 15 | ermioni
# Processing Record 23 of Set 15 | baghdad
# Processing Record 24 of Set 15 | blagoyevo
# Processing Record 25 of Set 15 | luanda
# Processing Record 26 of Set 15 | povenets
# Processing Record 27 of Set 15 | san julian
# Processing Record 28 of Set 15 | garowe
# Processing Record 29 of Set 15 | mogliano veneto
# Processing Record 30 of Set 15 | rodrigues alves
# Processing Record 31 of Set 15 | rio gallegos
# Processing Record 32 of Set 15 | wukari
# Processing Record 33 of Set 15 | igdir
# Processing Record 34 of Set 15 | chunhuhub
# Processing Record 35 of Set 15 | abalak
# Processing Record 36 of Set 15 | cervo
# Processing Record 37 of Set 15 | krasnoselkup
# Processing Record 38 of Set 15 | itacoatiara
# Processing Record 39 of Set 15 | neuquen
# Processing Record 40 of Set 15 | birnin kebbi
# Processing Record 41 of Set 15 | antibes
# Processing Record 42 of Set 15 | boende
# Processing Record 43 of Set 15 | dire
# Processing Record 44 of Set 15 | aktau
# Processing Record 45 of Set 15 | kazerun
# Processing Record 46 of Set 15 | veraval
# Processing Record 47 of Set 15 | torit
# Processing Record 48 of Set 15 | cagli
# Processing Record 49 of Set 15 | boa vista
# Processing Record 50 of Set 15 | chardara
# Processing Record 1 of Set 16 | goderich
# Processing Record 2 of Set 16 | januaria
# Processing Record 3 of Set 16 | kathmandu
# Processing Record 4 of Set 16 | adre
# Processing Record 5 of Set 16 | benguela
# Processing Record 6 of Set 16 | hammerfest
# Processing Record 7 of Set 16 | barkot
# Processing Record 8 of Set 16 | lamu
# Processing Record 9 of Set 16 | beterou
# Processing Record 10 of Set 16 | talbahat
# Processing Record 11 of Set 16 | vestbygda
# City not found. Skipping...
# Processing Record 12 of Set 16 | chodavaram
# Processing Record 13 of Set 16 | hajnowka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     East London -33.02  27.91     69.80        88          75       14.99
# 1           Roald  62.58   6.13     44.60        65          20       10.29
# 2     Clyde River  70.47 -68.59     -4.00        83          75       16.11
# 3        San Juan -31.54 -68.54     89.69        30           1       15.08
# 4    Quatre Cocos -20.21  57.76     77.00        78          75       11.41
# 5       Jamestown  42.10 -79.24     39.00        69          75       13.87
# 6         Copiapo -27.37 -70.33     69.80        52           0        8.05
# 7      Porto Novo   6.50   2.60     84.20        79          40       12.75
# 8           Izhma  65.01  53.91     15.01        94          94        4.97
# 9  Ribeira Grande  38.52 -28.70     57.20        67          40        6.93
#
#   Country                 Date       Description
# 0      ZA  2020-11-28 17:23:20     broken clouds
# 1      NO  2020-11-28 17:23:20        few clouds
# 2      CA  2020-11-28 17:23:20        light snow
# 3      AR  2020-11-28 17:23:20         clear sky
# 4      MU  2020-11-28 17:23:20     broken clouds
# 5      US  2020-11-28 17:23:20     broken clouds
# 6      CL  2020-11-28 17:23:14         clear sky
# 7      BJ  2020-11-28 17:23:21  scattered clouds
# 8      RU  2020-11-28 17:23:21   overcast clouds
# 9      PT  2020-11-28 17:23:21  scattered clouds

# %%
# Reorder the columns

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Georgetown      MY   5.41  100.34     80.60        88          20
# 1  Bahia De Caraquez      EC  -0.60  -80.42     73.40        78          20
# 2           Coquimbo      CL -29.95  -71.34     55.40        93           0
# 3            Ushuaia      AR -54.80  -68.30     39.20        69          40
# 4        East London      ZA -33.02   27.91     64.49        77          73
# 5            Husavik      IS  66.04  -17.34     35.60        43          20
# 6             Nazare      BR -13.04  -39.01     69.71        95           1
# 7            Qaanaaq      GL  77.48  -69.36     -2.69        82         100
# 8      Saint Andrews      US  34.05  -81.13     55.40        93          75
# 9            Mchinji      MW -13.80   32.88     65.07        87         100
#
#    Wind Speed       Description
# 0        5.82        few clouds
# 1        9.17        few clouds
# 2        8.05         clear sky
# 3        5.82  scattered clouds
# 4       21.54     broken clouds
# 5       16.11        few clouds
# 6        2.35         clear sky
# 7        4.94   overcast clouds
# 8        1.28     broken clouds
# 9        4.09   overcast clouds

# %%
# create an output file in CSV format

# output_data_file = "Weather_Database/WeatherPy_Database.csv"
output_data_file = "WeatherPy_Database.csv"
# print(output_data_file)

# Export the city_data_df into the above csv

city_data_df.to_csv(output_data_file, index_label = "City_ID")
